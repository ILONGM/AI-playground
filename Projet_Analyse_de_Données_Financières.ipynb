# %% [markdown]
# <a href="https://colab.research.google.com/github/ILONGM/AI-playground/blob/main/Projet_Analyse_de_Donn%C3%A9es_Financi%C3%A8res.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import yfinance as yf

# %% [markdown]
# import de donnée depuis yahoo finance pour l'action totalenergies

# %%
ticker = "TTE"
data = yf.Ticker(ticker)
history = data.history(period="10y")
print(history.head())
print(history.columns)
# Out:
#                                 Open       High        Low      Close  \
# Date
# 2015-01-09 00:00:00-05:00  27.258011  27.307762  26.638887  26.887642
# 2015-01-12 00:00:00-05:00  26.832355  27.064525  26.362484  26.782604
# 2015-01-13 00:00:00-05:00  26.992679  27.191681  26.533863  26.821314
# 2015-01-14 00:00:00-05:00  26.766024  27.108754  26.539381  26.909750
# 2015-01-15 00:00:00-05:00  27.296703  27.363037  26.815775  27.059004
#
#                             Volume  Dividends  Stock Splits
# Date
# 2015-01-09 00:00:00-05:00  2510300        0.0           0.0
# 2015-01-12 00:00:00-05:00  2394800        0.0           0.0
# 2015-01-13 00:00:00-05:00  1811300        0.0           0.0
# 2015-01-14 00:00:00-05:00  1873100        0.0           0.0
# 2015-01-15 00:00:00-05:00  4339500        0.0           0.0
# Index(['Open', 'High', 'Low', 'Close', 'Volume', 'Dividends', 'Stock Splits'], dtype='object')

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
plt.figure()
history['Close'].plot()

plt.figure()
history['Dividends'].plot()
# Out:
# <Axes: xlabel='Date'>

# %%
print(history.isnull().sum())
print(history.isna().sum())

print(history.describe())
# Out:
# Open            0
# High            0
# Low             0
# Close           0
# Volume          0
# Dividends       0
# Stock Splits    0
# dtype: int64
# Open            0
# High            0
# Low             0
# Close           0
# Volume          0
# Dividends       0
# Stock Splits    0
# dtype: int64
#               Open         High          Low        Close        Volume  \
# count  2516.000000  2516.000000  2516.000000  2516.000000  2.516000e+03
# mean     40.320553    40.606063    39.997635    40.296166  1.978631e+06
# std      12.153327    12.198302    12.086691    12.136599  1.235413e+06
# min      17.175823    18.285116    16.044791    17.951599  4.643000e+05
# 25%      30.054232    30.248601    29.793250    30.042155  1.179350e+06
# 50%      37.488327    37.738576    37.218719    37.438873  1.660150e+06
# 75%      45.362124    45.811050    44.860867    45.474418  2.407500e+06
# max      71.704438    71.953980    71.186162    71.560471  1.827920e+07
#
# ...

# %%
df=pd.DataFrame(history)
div = df[df['Dividends']>0]['Dividends']
print(div)

div.plot(kind='bar')
# Out:
# Date
# 2015-03-18 00:00:00-04:00    0.689
# 2015-06-03 00:00:00-04:00    0.673
# 2015-09-23 00:00:00-04:00    0.688
# 2015-12-16 00:00:00-05:00    0.664
# 2016-03-16 00:00:00-04:00    0.674
# 2016-06-01 00:00:00-04:00    0.683
# 2016-09-22 00:00:00-04:00    0.686
# 2016-12-16 00:00:00-05:00    0.656
# 2017-03-15 00:00:00-04:00    0.645
# 2017-05-31 00:00:00-04:00    0.694
# 2017-09-21 00:00:00-04:00    0.742
# 2017-12-15 00:00:00-05:00    0.734
# 2018-03-15 00:00:00-04:00    0.764
# 2018-06-07 00:00:00-04:00    0.730
# 2018-09-21 00:00:00-04:00    0.744
# 2018-12-14 00:00:00-05:00    0.727
# 2019-03-15 00:00:00-04:00    0.724
# 2019-06-07 00:00:00-04:00    0.713
# 2019-09-25 00:00:00-04:00    0.731
# 2020-01-02 00:00:00-05:00    0.734
# 2020-03-26 00:00:00-04:00    0.760
# 2020-06-25 00:00:00-04:00    0.769
# 2020-09-23 00:00:00-04:00    0.780
# 2020-12-30 00:00:00-05:00    0.808
# 2021-03-23 00:00:00-04:00    0.785
# 2021-06-22 00:00:00-04:00    0.803
# ...
